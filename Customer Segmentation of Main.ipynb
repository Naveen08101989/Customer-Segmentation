# %%
import pandas as pd
import numpy as np
from IPython.display import display
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# Ignore specific UserWarnings
warnings.filterwarnings("ignore", category=UserWarning)

# Reset warnings to the default behavior (optional)
warnings.resetwarnings()

# %%
os.chdir('C:\\Users\\DELL\\Desktop\\Python Power BI& ML Projects\\Customer-Segments-master\\')

# %%
data = pd.read_csv("customers.csv")
data
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicatessen
# 0            1338
# 1            1776
# 2            7844
# 3            1788
# 4            5185
# ..            ...
# 435          2204
# 436          2346
# 437          1867
# 438          2125
# 439            52
#
# [440 rows x 8 columns]

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669  9656     7561     214              2674
# 1        2       3   7057  9810     9568    1762              3293
# 2        2       3   6353  8808     7684    2405              3516
# 3        1       3  13265  1196     4221    6404               507
# 4        2       3  22615  5410     7198    3915              1777
#
#    Delicatessen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185

# %%
data.tail()
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicatessen
# 435          2204
# 436          2346
# 437          1867
# 438          2125
# 439            52

# %%
data.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper  Delicatessen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        816.500000    965.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicatessen      440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %%
data.columns
# Out:
# Index(['Channel', 'Region', 'Fresh', 'Milk', 'Grocery', 'Frozen',
#        'Detergents_Paper', 'Delicatessen'],
#       dtype='object')

# %%
 data.drop(['Region', 'Channel'], axis = 1, inplace = True)

# %%
data
# Out:
#      Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0    12669   9656     7561     214              2674          1338
# 1     7057   9810     9568    1762              3293          1776
# 2     6353   8808     7684    2405              3516          7844
# 3    13265   1196     4221    6404               507          1788
# 4    22615   5410     7198    3915              1777          5185
# ..     ...    ...      ...     ...               ...           ...
# 435  29703  12051    16027   13135               182          2204
# 436  39228   1431      764    4510                93          2346
# 437  14531  15488    30243     437             14841          1867
# 438  10290   1981     2232    1038               168          2125
# 439   2787   1698     2510      65               477            52
#
# [440 rows x 6 columns]

# %%
display(data.describe())
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# count     440.000000    440.000000    440.000000    440.000000
# mean    12000.297727   5796.265909   7951.277273   3071.931818
# std     12647.328865   7380.377175   9503.162829   4854.673333
# min         3.000000     55.000000      3.000000     25.000000
# 25%      3127.750000   1533.000000   2153.000000    742.250000
# 50%      8504.000000   3627.000000   4755.500000   1526.000000
# 75%     16933.750000   7190.250000  10655.750000   3554.250000
# max    112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper  Delicatessen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# 75%         3922.000000   1820.250000
# max        40827.000000  47943.000000

# %%
#Implementation: Selecting Samples

indices = [25,50,75]

samples = pd.DataFrame(data.loc[indices], columns = data.keys()).reset_index(drop = True)
print("Chosen samples of wholesale customers dataset:")
display(samples)
# Out:
# Chosen samples of wholesale customers dataset:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  16165  4230     7595     201              4003            57
# 1   6269  1095     1980    3860               609          2162
# 2  20398  1137        3    4407                 3           975

# %%
plt.figure(figsize=(16,5))
sns.set(font_scale = 1.3)
plt.title("Percentile for each sample")
pct = (data.rank(pct=True).loc[indices]*100).astype(int)
sns.heatmap(pct.transpose(), linewidth = 0.5, cmap=sns.color_palette("coolwarm", 7), annot = True)
plt.show()

# %%
#Customer Index : 25 (Index 0)
Major Spending: Fresh, DetergentS_Paper (Based on "HeatMap" & "> mean_value")
Medium Spending: Milk, Grocery (Based on "HeatMap" & "Around mean_value")
Minor Spending: Frozen, Delicatessen (Based on "HeatMap" & "< mean_value")
Conclusion: Small Retail Store.

    #Customer Index : 50 (Index 1)
Major Spending: Frozen, Delicatessen (Based on "HeatMap" & "> mean_value")
Medium Spending: Fresh, Detergents_Paper (Based on "HeatMap" & "Around mean_value")
Minor Spending: Milk, Grocery (Based on "HeatMap" & "< mean_value")
Conclusion: Resturent

    #Customer Index : 75 (Index 2)
Major Spending: Frozen, Fresh (Based on "HeatMap" & "> mean_value")
Medium Spending: Delicatessen (Based on "HeatMap" & "Around mean_value")
Minor Spending: Milk, Grocery, Detergents_Paper (Based on "HeatMap" & "< mean_value")
Conclusion: Supplier (with Small Resturent Business) / Supermarket (with attached Small Resturent)

# %%
#Implementation: Feature Relevance

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

features = list(data.columns)
for feature in features:
    new_data = data.drop([feature], axis = 1)
    X_train, X_test, y_train, y_test = train_test_split(new_data, data[feature], test_size=0.25, random_state=42)
    reg = DecisionTreeRegressor().fit(X_train, y_train)
    score = reg.score(X_test, y_test)
    print("R2 score for {} as dependent variable: {}".format(feature, score))
# Out:
# R2 score for Fresh as dependent variable: -0.2603281871263321
# R2 score for Milk as dependent variable: 0.20942542673035702
# R2 score for Grocery as dependent variable: 0.6828980266397626
# R2 score for Frozen as dependent variable: -0.24390367841039806
# R2 score for Detergents_Paper as dependent variable: 0.48890483174140287
# R2 score for Delicatessen as dependent variable: -2.5293430624044007

# %%
#Visualize Feature Distributions
pd.plotting.scatter_matrix(data,alpha=0.3, figsize=(14,8), diagonal = 'kde')
# Out:
# array([[<AxesSubplot: xlabel='Fresh', ylabel='Fresh'>,
#         <AxesSubplot: xlabel='Milk', ylabel='Fresh'>,
#         <AxesSubplot: xlabel='Grocery', ylabel='Fresh'>,
#         <AxesSubplot: xlabel='Frozen', ylabel='Fresh'>,
#         <AxesSubplot: xlabel='Detergents_Paper', ylabel='Fresh'>,
#         <AxesSubplot: xlabel='Delicatessen', ylabel='Fresh'>],
#        [<AxesSubplot: xlabel='Fresh', ylabel='Milk'>,
#         <AxesSubplot: xlabel='Milk', ylabel='Milk'>,
#         <AxesSubplot: xlabel='Grocery', ylabel='Milk'>,
#         <AxesSubplot: xlabel='Frozen', ylabel='Milk'>,
#         <AxesSubplot: xlabel='Detergents_Paper', ylabel='Milk'>,
#         <AxesSubplot: xlabel='Delicatessen', ylabel='Milk'>],
#        [<AxesSubplot: xlabel='Fresh', ylabel='Grocery'>,
#         <AxesSubplot: xlabel='Milk', ylabel='Grocery'>,
#         <AxesSubplot: xlabel='Grocery', ylabel='Grocery'>,
#         <AxesSubplot: xlabel='Frozen', ylabel='Grocery'>,
#         <AxesSubplot: xlabel='Detergents_Paper', ylabel='Grocery'>,
#         <AxesSubplot: xlabel='Delicatessen', ylabel='Grocery'>],
#        [<AxesSubplot: xlabel='Fresh', ylabel='Frozen'>,
#         <AxesSubplot: xlabel='Milk', ylabel='Frozen'>,
#         <AxesSubplot: xlabel='Grocery', ylabel='Frozen'>,
#         <AxesSubplot: xlabel='Frozen', ylabel='Frozen'>,
#         <AxesSubplot: xlabel='Detergents_Paper', ylabel='Frozen'>,
#         <AxesSubplot: xlabel='Delicatessen', ylabel='Frozen'>],
#        [<AxesSubplot: xlabel='Fresh', ylabel='Detergents_Paper'>,
#         <AxesSubplot: xlabel='Milk', ylabel='Detergents_Paper'>,
#         <AxesSubplot: xlabel='Grocery', ylabel='Detergents_Paper'>,
#         <AxesSubplot: xlabel='Frozen', ylabel='Detergents_Paper'>,
#         <AxesSubplot: xlabel='Detergents_Paper', ylabel='Detergents_Paper'>,
#         <AxesSubplot: xlabel='Delicatessen', ylabel='Detergents_Paper'>],
#        [<AxesSubplot: xlabel='Fresh', ylabel='Delicatessen'>,
#         <AxesSubplot: xlabel='Milk', ylabel='Delicatessen'>,
#         <AxesSubplot: xlabel='Grocery', ylabel='Delicatessen'>,
#         <AxesSubplot: xlabel='Frozen', ylabel='Delicatessen'>,
#         <AxesSubplot: xlabel='Detergents_Paper', ylabel='Delicatessen'>,
#         <AxesSubplot: xlabel='Delicatessen', ylabel='Delicatessen'>]],
#       dtype=object)

# %%
# Assuming 'data' is your DataFrame and 'samples' is a list of samples
log_data = np.log(data)
log_samples = np.log(samples)

# Use the scatter_matrix from pandas.plotting instead
pd.plotting.scatter_matrix(log_data, alpha=0.3, figsize=(14, 8), diagonal='kde')
plt.show()

# %%
#Observation

display(log_samples)
# Out:
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 0  9.690604  8.349957  8.935245  5.303305          8.294799      4.043051
# 1  8.743372  6.998510  7.590852  8.258422          6.411818      7.678789
# 2  9.923192  7.036148  1.098612  8.390949          1.098612      6.882437

# %%
print("Distribution before Normalizing the Data")
sns.set(color_codes = True)
plt.show()
sns.distplot(data['Fresh'], rug=True, hist=False)
sns.distplot(data['Milk'], rug=True, hist=False)
sns.distplot(data['Grocery'], rug=True, hist=False)
sns.distplot(data['Frozen'], rug=True, hist=False)
sns.distplot(data['Detergents_Paper'], rug=True, hist=False)
sns.distplot(data['Delicatessen'], rug=True, hist=False)
plt.show()
# Out:
# Distribution before Normalizing the Data
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\1742262434.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Fresh'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\1742262434.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Milk'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\1742262434.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Grocery'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\1742262434.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Frozen'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\1742262434.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Detergents_Paper'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\1742262434.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Delicatessen'], rug=True, hist=False)

# %%
sns.displot(data['Fresh'], rug=True, kind='kde')
sns.displot(data['Milk'], rug=True, kind='kde')
sns.displot(data['Grocery'], rug=True, kind='kde')
sns.displot(data['Frozen'], rug=True, kind='kde')
sns.displot(data['Detergents_Paper'], rug=True, kind='kde')
sns.displot(data['Delicatessen'], rug=True, kind='kde')

plt.show()

# %%
print("Distribution after Normalizing the Data")
sns.set(color_codes = True)
plt.show()
sns.distplot(log_data['Fresh'], rug=True, hist=False)
sns.distplot(log_data['Milk'], rug=True, hist=False)
sns.distplot(log_data['Grocery'], rug=True, hist=False)
sns.distplot(log_data['Frozen'], rug=True, hist=False)
sns.distplot(log_data['Detergents_Paper'], rug=True, hist=False)
sns.distplot(log_data['Delicatessen'], rug=True, hist=False)
plt.show()
# Out:
# Distribution after Normalizing the Data
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\3198134662.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data['Fresh'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\3198134662.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data['Milk'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\3198134662.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data['Grocery'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\3198134662.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data['Frozen'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\3198134662.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data['Detergents_Paper'], rug=True, hist=False)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\3198134662.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(log_data['Delicatessen'], rug=True, hist=False)

# %%
#Implementation: Outlier Detection

for feature in log_data.keys():
    
    Q1 = np.percentile(log_data[feature],25)
    Q3 = np.percentile(log_data[feature],75)
    step = (Q3-Q1)*1.5
    
    print("Data points considered outliers for the feature '{}':".format(feature))
    display(log_data[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))])
outliers  = [65,66,75,128,154]
good_data = log_data.drop(log_data.index[outliers]).reset_index(drop = True)
# Out:
# Data points considered outliers for the feature 'Fresh':
#         Fresh       Milk    Grocery    Frozen  Detergents_Paper  Delicatessen
# 65   4.442651   9.950323  10.732651  3.583519         10.095388      7.260523
# 66   2.197225   7.335634   8.911530  5.164786          8.151333      3.295837
# 81   5.389072   9.163249   9.575192  5.645447          8.964184      5.049856
# 95   1.098612   7.979339   8.740657  6.086775          5.407172      6.563856
# 96   3.135494   7.869402   9.001839  4.976734          8.262043      5.379897
# 128  4.941642   9.087834   8.248791  4.955827          6.967909      1.098612
# 171  5.298317  10.160530   9.894245  6.478510          9.079434      8.740337
# 193  5.192957   8.156223   9.917982  6.865891          8.633731      6.501290
# 218  2.890372   8.923191   9.629380  7.158514          8.475746      8.759669
# 304  5.081404   8.917311  10.117510  6.424869          9.374413      7.787382
# 305  5.493061   9.468001   9.088399  6.683361          8.271037      5.351858
# 338  1.098612   5.808142   8.856661  9.655090          2.708050      6.309918
# 353  4.762174   8.742574   9.961898  5.429346          9.069007      7.013016
# 355  5.247024   6.588926   7.606885  5.501258          5.214936      4.844187
# 357  3.610918   7.150701  10.011086  4.919981          8.816853      4.700480
# 412  4.574711   8.190077   9.425452  4.584967          7.996317      4.127134
# Data points considered outliers for the feature 'Milk':
#          Fresh       Milk    Grocery    Frozen  Detergents_Paper  Delicatessen
# 86   10.039983  11.205013  10.377047  6.894670          9.906981      6.805723
# 98    6.220590   4.718499   6.656727  6.796824          4.025352      4.882802
# 154   6.432940   4.007333   4.919981  4.317488          1.945910      2.079442
# 356  10.029503   4.897840   5.384495  8.057377          2.197225      6.306275
# Data points considered outliers for the feature 'Grocery':
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 75   9.923192  7.036148  1.098612  8.390949          1.098612      6.882437
# 154  6.432940  4.007333  4.919981  4.317488          1.945910      2.079442
# Data points considered outliers for the feature 'Frozen':
#          Fresh      Milk    Grocery     Frozen  Detergents_Paper  Delicatessen
# 38    8.431853  9.663261   9.723703   3.496508          8.847360      6.070738
# 57    8.597297  9.203618   9.257892   3.637586          8.932213      7.156177
# 65    4.442651  9.950323  10.732651   3.583519         10.095388      7.260523
# 145  10.000569  9.034080  10.457143   3.737670          9.440738      8.396155
# 175   7.759187  8.967632   9.382106   3.951244          8.341887      7.436617
# 264   6.978214  9.177714   9.645041   4.110874          8.696176      7.142827
# 325  10.395650  9.728181   9.519735  11.016479          7.148346      8.632128
# 420   8.402007  8.569026   9.490015   3.218876          8.827321      7.239215
# 429   9.060331  7.467371   8.183118   3.850148          4.430817      7.824446
# 439   7.932721  7.437206   7.828038   4.174387          6.167516      3.951244
# Data points considered outliers for the feature 'Detergents_Paper':
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 75   9.923192  7.036148  1.098612  8.390949          1.098612      6.882437
# 161  9.428190  6.291569  5.645447  6.995766          1.098612      7.711101
# Data points considered outliers for the feature 'Delicatessen':
#          Fresh       Milk    Grocery     Frozen  Detergents_Paper  \
# 66    2.197225   7.335634   8.911530   5.164786          8.151333
# 109   7.248504   9.724899  10.274568   6.511745          6.728629
# 128   4.941642   9.087834   8.248791   4.955827          6.967909
# 137   8.034955   8.997147   9.021840   6.493754          6.580639
# 142  10.519646   8.875147   9.018332   8.004700          2.995732
# 154   6.432940   4.007333   4.919981   4.317488          1.945910
# 183  10.514529  10.690808   9.911952  10.505999          5.476464
# 184   5.789960   6.822197   8.457443   4.304065          5.811141
# 187   7.798933   8.987447   9.192075   8.743372          8.148735
# 203   6.368187   6.529419   7.703459   6.150603          6.860664
# 233   6.871091   8.513988   8.106515   6.842683          6.013715
# 285  10.602965   6.461468   8.188689   6.948897          6.077642
# 289  10.663966   5.655992   6.154858   7.235619          3.465736
# 343   7.431892   8.848509  10.177932   7.283448          9.646593
#
#      Delicatessen
# 66       3.295837
# 109      1.098612
# 128      1.098612
# 137      3.583519
# 142      1.098612
# 154      2.079442
# 183     10.777768
# 184      2.397895
# 187      1.098612
# 203      2.890372
# 233      1.945910
# 285      2.890372
# 289      3.091042
# 343      3.610918

# %%
#Feature Transformation


#Implementation: PCA

from sklearn.decomposition import PCA
import pandas as pd

def pca_results(data, pca):
    # Create a DataFrame with the principal components and their explained variance
    components = pd.DataFrame(pca.components_, columns=data.columns)
    explained_variance = pca.explained_variance_ratio_.reshape(-1, 1)
    components['Explained Variance'] = explained_variance

    # Display the results
    return components

# Assuming you have a 'good_data' DataFrame and 'pca' object
pca = PCA(n_components=6).fit(good_data)
pca_results_df = pca_results(good_data, pca)
print(pca_results_df)
# Out:
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen  \
# 0  0.167464 -0.401439 -0.438111  0.178210         -0.751426     -0.149871
# 1 -0.685935 -0.167228 -0.070729 -0.500542         -0.042444     -0.494147
# 2 -0.677389  0.040205 -0.019533  0.315043         -0.211702      0.628551
# 3 -0.204293  0.012811  0.055676  0.785449          0.209614     -0.542340
# 4 -0.002614  0.719238  0.355386 -0.033086         -0.558154     -0.209186
# 5  0.029156 -0.540183  0.820533  0.020541         -0.182388      0.019748
#
#    Explained Variance
# 0            0.443025
# 1            0.263792
# 2            0.123064
# 3            0.101209
# 4            0.048502
# 5            0.020408

# %%
#display(pca_results)
#print(pca_results['Explained Variance'].cumsum())

# Assuming 'good_data' is your DataFrame and 'log_samples' is a NumPy array
pca = PCA(n_components=6).fit(good_data)
pca_samples = pca.transform(log_samples)
pca_results_df = pca_results(good_data, pca)

# Display the result
display(pca_results_df)

# Print the cumulative sum of explained variance
print(pca_results_df['Explained Variance'].cumsum())
# Out:
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen  \
# 0  0.167464 -0.401439 -0.438111  0.178210         -0.751426     -0.149871
# 1 -0.685935 -0.167228 -0.070729 -0.500542         -0.042444     -0.494147
# 2 -0.677389  0.040205 -0.019533  0.315043         -0.211702      0.628551
# 3 -0.204293  0.012811  0.055676  0.785449          0.209614     -0.542340
# 4 -0.002614  0.719238  0.355386 -0.033086         -0.558154     -0.209186
# 5  0.029156 -0.540183  0.820533  0.020541         -0.182388      0.019748
#
#    Explained Variance
# 0            0.443025
# 1            0.263792
# 2            0.123064
# 3            0.101209
# 4            0.048502
# 5            0.020408
# 0    0.443025
# 1    0.706817
# 2    0.829881
# 3    0.931090
# 4    0.979592
# 5    1.000000
# Name: Explained Variance, dtype: float64

# %%
#Observation
#display(pd.DataFrame(np.round(pca_samples, 4), columns = pca_results.index.values))
display(pd.DataFrame(np.round(pca_samples, 4), columns=pca_results_df.index.values))
# Out:
#         0       1       2       3       4       5
# 0 -1.2292  1.5540 -3.2462  0.0043  0.1124 -0.0697
# 1  1.1404 -0.6710  0.9823  0.0603 -1.1423  0.0055
# 2  8.3026 -0.4747  0.9774 -1.1195 -0.2977 -4.3514

# %%
#Implementation: Dimensionality Reduction

pca = PCA(n_components=2).fit(good_data)
reduced_data = pca.transform(good_data)
pca_samples = pca.transform(log_samples)
reduced_data = pd.DataFrame(reduced_data, columns=['Dimension 1', 'Dimension 2'])

# %%
# Assuming 'good_data' is your DataFrame and 'log_samples' is a NumPy array
pca = PCA(n_components=6).fit(good_data)
pca_samples = pca.transform(log_samples)
pca_results_df = pca_results(good_data, pca)

# Display the result
display(pca_results_df)
# Out:
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen  \
# 0  0.167464 -0.401439 -0.438111  0.178210         -0.751426     -0.149871
# 1 -0.685935 -0.167228 -0.070729 -0.500542         -0.042444     -0.494147
# 2 -0.677389  0.040205 -0.019533  0.315043         -0.211702      0.628551
# 3 -0.204293  0.012811  0.055676  0.785449          0.209614     -0.542340
# 4 -0.002614  0.719238  0.355386 -0.033086         -0.558154     -0.209186
# 5  0.029156 -0.540183  0.820533  0.020541         -0.182388      0.019748
#
#    Explained Variance
# 0            0.443025
# 1            0.263792
# 2            0.123064
# 3            0.101209
# 4            0.048502
# 5            0.020408

# %%
from IPython.display import display
import visuals as vs

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=6).fit(good_data)
pca_samples = pca.transform(log_samples)
pca_results = vs.pca_results(good_data, pca)

# %%
display(pca_results)
print(pca_results['Explained Variance'].cumsum())
# Out:
#              Explained Variance   Fresh    Milk  Grocery  Frozen  \
# Dimension 1              0.4430  0.1675 -0.4014  -0.4381  0.1782
# Dimension 2              0.2638 -0.6859 -0.1672  -0.0707 -0.5005
# Dimension 3              0.1231 -0.6774  0.0402  -0.0195  0.3150
# Dimension 4              0.1012 -0.2043  0.0128   0.0557  0.7854
# Dimension 5              0.0485 -0.0026  0.7192   0.3554 -0.0331
# Dimension 6              0.0204  0.0292 -0.5402   0.8205  0.0205
#
#              Detergents_Paper  Delicatessen
# Dimension 1           -0.7514       -0.1499
# Dimension 2           -0.0424       -0.4941
# Dimension 3           -0.2117        0.6286
# Dimension 4            0.2096       -0.5423
# Dimension 5           -0.5582       -0.2092
# Dimension 6           -0.1824        0.0197
# Dimension 1    0.4430
# Dimension 2    0.7068
# Dimension 3    0.8299
# Dimension 4    0.9311
# Dimension 5    0.9796
# Dimension 6    1.0000
# Name: Explained Variance, dtype: float64

# %%
#Observation
display(pd.DataFrame(np.round(pca_samples, 4), columns = pca_results.index.values))
# Out:
#    Dimension 1  Dimension 2  Dimension 3  Dimension 4  Dimension 5  \
# 0      -1.2292       1.5540      -3.2462       0.0043       0.1124
# 1       1.1404      -0.6710       0.9823       0.0603      -1.1423
# 2       8.3026      -0.4747       0.9774      -1.1195      -0.2977
#
#    Dimension 6
# 0      -0.0697
# 1       0.0055
# 2      -4.3514

# %%
#Implementation: Dimensionality Reduction
pca = PCA(n_components=2).fit(good_data)
reduced_data = pca.transform(good_data)
pca_samples = pca.transform(log_samples)
reduced_data = pd.DataFrame(reduced_data, columns=['Dimension 1', 'Dimension 2'])


vs.pca_results(good_data, pca)
# Out:
#              Explained Variance   Fresh    Milk  Grocery  Frozen  \
# Dimension 1              0.4430  0.1675 -0.4014  -0.4381  0.1782
# Dimension 2              0.2638 -0.6859 -0.1672  -0.0707 -0.5005
#
#              Detergents_Paper  Delicatessen
# Dimension 1           -0.7514       -0.1499
# Dimension 2           -0.0424       -0.4941

# %%
#Observation
display(pd.DataFrame(np.round(pca_samples, 4), columns = ['Dimension 1', 'Dimension 2']))
# Out:
#    Dimension 1  Dimension 2
# 0      -1.2292       1.5540
# 1       1.1404      -0.6710
# 2       8.3026      -0.4747

# %%
#Visualizing a Biplot
vs.biplot(good_data, reduced_data, pca)
# Out:
# <AxesSubplot: title={'center': 'PC plane with original feature projections.'}, xlabel='Dimension 1', ylabel='Dimension 2'>

# %%
#Implementation: Creating Clusters
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

def produceGaussianMixture(k):
    clusterer = GaussianMixture(n_components=k, random_state=0).fit(reduced_data)
    preds = clusterer.predict(reduced_data)
    centers = clusterer.means_ 
    sample_preds = clusterer.predict(pca_samples)
    score = silhouette_score(reduced_data,preds)
    return score

results = pd.DataFrame(columns=['Silhouette Score'])
results.columns.name = 'Number of Clusters'    
for k in range(2,13):
    score = produceGaussianMixture(k) 
    results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))

display(results)

import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# Your code here

# Reset warnings to the default behavior (optional)
warnings.resetwarnings()
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\AppData\Local\Temp\ipykernel_11352\464014722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append(pd.DataFrame([score],columns=['Silhouette Score'],index=[k]))
#     Silhouette Score
# 2           0.421917
# 3           0.374202
# 4           0.329080
# 5           0.305875
# 6           0.224815
# 7           0.274334
# 8           0.344232
# 9           0.334324
# 10          0.339956
# 11          0.319716
# 12          0.321553

# %%
#Cluster Visualization
clusterer = GaussianMixture(n_components = 2, random_state=0).fit(reduced_data)
preds = clusterer.predict(reduced_data)
centers = clusterer.means_
vs.cluster_results(reduced_data, preds, centers, pca_samples)
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\DELL\Desktop\Python Power BI& ML Projects\Customer-Segments-master\visuals.py:65: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` instead.
#   cmap = cm.get_cmap('gist_rainbow')

# %%
log_centers = pca.inverse_transform(centers)
true_centers = np.exp(log_centers)
segments = ['Segment {}'.format(i) for i in range(0,len(centers))]
true_centers = pd.DataFrame(np.round(true_centers), columns = data.keys())
true_centers.index = segments
display(true_centers)
# Out:
#             Fresh    Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# Segment 0  8953.0  2114.0   2765.0  2075.0             353.0         732.0
# Segment 1  3552.0  7837.0  12219.0   870.0            4696.0         962.0

# %%
display(data.mean())
# Out:
# Fresh               12000.297727
# Milk                 5796.265909
# Grocery              7951.277273
# Frozen               3071.931818
# Detergents_Paper     2881.493182
# Delicatessen         1524.870455
# dtype: float64

# %%
plt.figure()
plt.axes().set_title("Segment 0")
sns.barplot(x=true_centers.columns.values, y=true_centers.iloc[0].values)
plt.figure()
plt.axes().set_title("Segment 1")
sns.barplot(x=true_centers.columns.values, y=true_centers.iloc[0].values)
# Out:
# <AxesSubplot: title={'center': 'Segment 1'}>

# %%
sample_preds = clusterer.predict(pca_samples)
for i, pred in enumerate(sample_preds):
    print("Sample point", i, "predicted to be in Cluster", pred)
# Out:
# Sample point 0 predicted to be in Cluster 1
# Sample point 1 predicted to be in Cluster 0
# Sample point 2 predicted to be in Cluster 0
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(

# %%
samples
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  16165  4230     7595     201              4003            57
# 1   6269  1095     1980    3860               609          2162
# 2  20398  1137        3    4407                 3           975

# %%
#Visualizing Underlying Distributions
vs.channel_results(reduced_data, outliers, pca_samples)
# Out:
# C:\Users\DELL\Desktop\Python Power BI& ML Projects\Customer-Segments-master\visuals.py:147: PendingDeprecationWarning: The get_cmap function will be deprecated in a future version. Use ``matplotlib.colormaps[name]`` instead.
#   cmap = cm.get_cmap('gist_rainbow')
